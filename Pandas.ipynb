# %% [markdown]
# # Pandas
#
# Series - серия (вектора-столбец)
#
# Dataframe - таблица данных (датафрейм)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
salaries = pd.Series(data = [400, 300, 200, 250], index = ["Andrew", "Sasha", "Masha", "Bob"])

# %%
salaries
# Out:
# Andrew    400
# Sasha     300
# Masha     200
# Bob       250
# dtype: int64

# %%
type(salaries)
# Out:
# pandas.core.series.Series

# %%
salaries["Andrew"]
# Out:
# 400

# %%
salaries.Andrew
# Out:
# 400

# %%
salaries["Bob"] = 1000

# %%
salaries
# Out:
# Andrew     400
# Sasha      300
# Masha      200
# Bob       1000
# dtype: int64

# %%
salaries["Bob"] = np.NAN

# %%
salaries
# Out:
# Andrew    400.0
# Sasha     300.0
# Masha     200.0
# Bob         NaN
# dtype: float64

# %%
salaries.mean()
# Out:
# 300.0

# %%
salaries.max()
# Out:
# 400.0

# %%
salaries.min()
# Out:
# 200.0

# %%
salaries["George"] = 1000000

# %%
salaries
# Out:
# Andrew        400.0
# Sasha         300.0
# Masha         200.0
# Bob             NaN
# George    1000000.0
# dtype: float64

# %%
salaries.mean(), salaries.median()
# Out:
# (250225.0, 350.0)

# %%
salaries.fillna(salaries.median())
# Out:
# Andrew        400.0
# Sasha         300.0
# Masha         200.0
# Bob           350.0
# George    1000000.0
# dtype: float64

# %%
salaries
# Out:
# Andrew        400.0
# Sasha         300.0
# Masha         200.0
# Bob             NaN
# George    1000000.0
# dtype: float64

# %%
salaries.fillna(salaries.median(), inplace = True)

# %%
salaries
# Out:
# Andrew        400.0
# Sasha         300.0
# Masha         200.0
# Bob           350.0
# George    1000000.0
# dtype: float64

# %% [markdown]
# # Dataframe

# %%
df1 = pd.DataFrame(data = np.random.randn(5,3),
                  index = ["s1", "s2", "s3", "s4", "s5"],
                  columns = ["col1", "col2", "col3"])

# %%
df1
# Out:
#         col1      col2      col3
# s1 -0.092392  0.461964 -0.526795
# s2 -2.844305  0.783832  0.345941
# s3 -0.247291  0.940923 -0.757663
# s4 -1.271157  0.438435 -0.719479
# s5 -0.355918  0.334545  0.876417

# %%
print(df1)
# Out:
#         col1      col2      col3
# s1 -0.092392  0.461964 -0.526795
# s2 -2.844305  0.783832  0.345941
# s3 -0.247291  0.940923 -0.757663
# s4 -1.271157  0.438435 -0.719479
# s5 -0.355918  0.334545  0.876417

# %%
# 2-й способ создания датафрейма
df2 = pd.DataFrame({"A": np.random.random(5),
                   "B": ["a", "b", "c", "d", "e"],
                   "C": np.arange(5) > 2})

# %%
df2
# Out:
#           A  B      C
# 0  0.339493  a  False
# 1  0.214503  b  False
# 2  0.712962  c  False
# 3  0.286780  d   True
# 4  0.796636  e   True

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, s1 to s5
# Data columns (total 3 columns):
# col1    5 non-null float64
# col2    5 non-null float64
# col3    5 non-null float64
# dtypes: float64(3)
# memory usage: 160.0+ bytes

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
# A    5 non-null float64
# B    5 non-null object
# C    5 non-null bool
# dtypes: bool(1), float64(1), object(1)
# memory usage: 165.0+ bytes

# %%
df1.shape
# Out:
# (5, 3)

# %%
df2.shape
# Out:
# (5, 3)

# %% [markdown]
# # Обращение к элементам датафреймов

# %%
df2
# Out:
#           A  B      C
# 0  0.339493  a  False
# 1  0.214503  b  False
# 2  0.712962  c  False
# 3  0.286780  d   True
# 4  0.796636  e   True

# %%
df2.loc[[1,4]]
# Out:
#           A  B      C
# 1  0.214503  b  False
# 4  0.796636  e   True

# %%
df2.loc[[1,4],["A", "B"]]
# Out:
#           A  B
# 1  0.214503  b
# 4  0.796636  e

# %%
df2.iloc[:3]
# Out:
#           A  B      C
# 0  0.339493  a  False
# 1  0.214503  b  False
# 2  0.712962  c  False

# %%
df2.iloc[:3,:2]
# Out:
#           A  B
# 0  0.339493  a
# 1  0.214503  b
# 2  0.712962  c

# %%
df2.iloc[1:3,1:2]
# Out:
#    B
# 1  b
# 2  c

# %%
df2.iloc[1,1]
# Out:
# 'b'

# %%
df2["A"]
# Out:
# 0    0.339493
# 1    0.214503
# 2    0.712962
# 3    0.286780
# 4    0.796636
# Name: A, dtype: float64

# %%
df2["A"][1]
# Out:
# 0.21450251219501437

# %%
df1.columns
# Out:
# Index(['col1', 'col2', 'col3'], dtype='object')

# %%
df1["col1"]
# Out:
# s1   -0.092392
# s2   -2.844305
# s3   -0.247291
# s4   -1.271157
# s5   -0.355918
# Name: col1, dtype: float64

# %%
df1["col1"]["s1"]
# Out:
# -0.0923920953739138

# %%
type(df1["col1"])
# Out:
# pandas.core.series.Series

# %%
df2[["A","B"]].iloc[:3]
# Out:
#           A  B
# 0  0.339493  a
# 1  0.214503  b
# 2  0.712962  c

# %%
df1.columns, df2.columns
# Out:
# (Index(['col1', 'col2', 'col3'], dtype='object'),
#  Index(['A', 'B', 'C'], dtype='object'))

# %%
df1.columns = ['A', 'B', 'C']

# %%
df1
# Out:
#            A         B         C
# s1 -0.620636  0.399965  1.091773
# s2 -0.134958 -0.624165 -2.494567
# s3 -0.231712 -0.396180 -0.197723
# s4 -0.215869  0.294207  0.559878
# s5 -0.387910 -0.167354 -0.245764

# %%
df3 = df1.append(df2)

# %%
df3
# Out:
#            A         B         C
# s1 -0.620636  0.399965  1.091773
# s2 -0.134958 -0.624165 -2.494567
# s3 -0.231712  -0.39618 -0.197723
# s4 -0.215869  0.294207  0.559878
# s5 -0.387910 -0.167354 -0.245764
# 0   0.039401         a  0.000000
# 1   0.913397         b  0.000000
# 2   0.816889         c  0.000000
# 3   0.521787         d  1.000000
# 4   0.956985         e  1.000000

# %%
df3.head(2)
# Out:
#            A         B         C
# s1 -0.620636  0.399965  1.091773
# s2 -0.134958 -0.624165 -2.494567

# %%
df3.tail(2)
# Out:
#           A  B    C
# 3  0.521787  d  1.0
# 4  0.956985  e  1.0

# %%
df3.reset_index(inplace = True)

# %%
df3
# Out:
#   index         A         B         C
# 0    s1 -0.620636  0.399965  1.091773
# 1    s2 -0.134958 -0.624165 -2.494567
# 2    s3 -0.231712  -0.39618 -0.197723
# 3    s4 -0.215869  0.294207  0.559878
# 4    s5 -0.387910 -0.167354 -0.245764
# 5     0  0.039401         a  0.000000
# 6     1  0.913397         b  0.000000
# 7     2  0.816889         c  0.000000
# 8     3  0.521787         d  1.000000
# 9     4  0.956985         e  1.000000

# %%
df3.drop("index", axis = 1, inplace = True)

# %%
df1.index = range(5)

# %%
df1
# Out:
#           A         B         C
# 0 -0.620636  0.399965  1.091773
# 1 -0.134958 -0.624165 -2.494567
# 2 -0.231712 -0.396180 -0.197723
# 3 -0.215869  0.294207  0.559878
# 4 -0.387910 -0.167354 -0.245764

# %%
df1
# Out:
#           A         B         C
# 0 -0.620636  0.399965  1.091773
# 1 -0.134958 -0.624165 -2.494567
# 2 -0.231712 -0.396180 -0.197723
# 3 -0.215869  0.294207  0.559878
# 4 -0.387910 -0.167354 -0.245764

# %%
df2
# Out:
#           A  B      C
# 0  0.039401  a  False
# 1  0.913397  b  False
# 2  0.816889  c  False
# 3  0.521787  d   True
# 4  0.956985  e   True

# %%
df4 = pd.concat([df1,df2], axis = 1)

# %%
df4
# Out:
#           A         B         C         A  B      C
# 0 -0.620636  0.399965  1.091773  0.039401  a  False
# 1 -0.134958 -0.624165 -2.494567  0.913397  b  False
# 2 -0.231712 -0.396180 -0.197723  0.816889  c  False
# 3 -0.215869  0.294207  0.559878  0.521787  d   True
# 4 -0.387910 -0.167354 -0.245764  0.956985  e   True

# %%
df4.columns = ["A", "B", "C", "D", "E", "G"]

# %%
df4
# Out:
#           A         B         C         D  E      G
# 0 -0.620636  0.399965  1.091773  0.039401  a  False
# 1 -0.134958 -0.624165 -2.494567  0.913397  b  False
# 2 -0.231712 -0.396180 -0.197723  0.816889  c  False
# 3 -0.215869  0.294207  0.559878  0.521787  d   True
# 4 -0.387910 -0.167354 -0.245764  0.956985  e   True

# %%
df4.iloc[1:3,2:4] = np.NAN

# %%
df4
# Out:
#           A         B         C         D  E      G
# 0 -0.620636  0.399965  1.091773  0.039401  a  False
# 1 -0.134958 -0.624165       NaN       NaN  b  False
# 2 -0.231712 -0.396180       NaN       NaN  c  False
# 3 -0.215869  0.294207  0.559878  0.521787  d   True
# 4 -0.387910 -0.167354 -0.245764  0.956985  e   True

# %%
df4.isna().sum()
# Out:
# A    0
# B    0
# C    2
# D    2
# E    0
# G    0
# dtype: int64

# %%
df4.drop(["C", "D"], axis= 1)
# Out:
#           A         B  E      G
# 0 -0.620636  0.399965  a  False
# 1 -0.134958 -0.624165  b  False
# 2 -0.231712 -0.396180  c  False
# 3 -0.215869  0.294207  d   True
# 4 -0.387910 -0.167354  e   True

# %%
df4
# Out:
#           A         B         C         D  E      G
# 0 -0.620636  0.399965  1.091773  0.039401  a  False
# 1 -0.134958 -0.624165       NaN       NaN  b  False
# 2 -0.231712 -0.396180       NaN       NaN  c  False
# 3 -0.215869  0.294207  0.559878  0.521787  d   True
# 4 -0.387910 -0.167354 -0.245764  0.956985  e   True

# %%
df4.dropna(axis = 1)
# Out:
#           A         B  E      G
# 0 -0.620636  0.399965  a  False
# 1 -0.134958 -0.624165  b  False
# 2 -0.231712 -0.396180  c  False
# 3 -0.215869  0.294207  d   True
# 4 -0.387910 -0.167354  e   True

# %%
df4.fillna(df4.median())
# Out:
#           A         B         C         D  E      G
# 0 -0.620636  0.399965  1.091773  0.039401  a  False
# 1 -0.134958 -0.624165  0.559878  0.521787  b  False
# 2 -0.231712 -0.396180  0.559878  0.521787  c  False
# 3 -0.215869  0.294207  0.559878  0.521787  d   True
# 4 -0.387910 -0.167354 -0.245764  0.956985  e   True

# %% [markdown]
# # Первичный анализ данных в Pandas

# %%
df = pd.read_csv('data/beauty.csv', sep = ";")

# %%
df.head()
# Out:
#     wage  exper  union  goodhlth  black  female  married  service  educ  looks
# 0   5.73     30      0         1      0       1        1        1    14      4
# 1   4.28     28      0         1      0       1        1        0    12      3
# 2   7.96     35      0         1      0       1        0        0    10      4
# 3  11.57     38      0         1      0       0        1        1    16      3
# 4  11.42     27      0         1      0       0        1        0    16      3

# %%
df.shape
# Out:
# (1260, 10)

# %%
df.tail()
# Out:
#       wage  exper  union  goodhlth  black  female  married  service  educ  \
# 1255  1.61     25      0         1      1       1        0        1    12
# 1256  1.68      4      0         1      0       1        1        1    12
# 1257  3.29     35      0         1      1       1        0        1    12
# 1258  2.31     15      0         1      1       1        1        1    10
# 1259  1.92     24      0         0      0       1        0        1    16
#
#       looks
# 1255      3
# 1256      2
# 1257      3
# 1258      3
# 1259      3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 10 columns):
# wage        1260 non-null float64
# exper       1260 non-null int64
# union       1260 non-null int64
# goodhlth    1260 non-null int64
# black       1260 non-null int64
# female      1260 non-null int64
# married     1260 non-null int64
# service     1260 non-null int64
# educ        1260 non-null int64
# looks       1260 non-null int64
# dtypes: float64(1), int64(9)
# memory usage: 98.5 KB

# %%
df.columns
# Out:
# Index(['wage', 'exper', 'union', 'goodhlth', 'black', 'female', 'married',
#        'service', 'educ', 'looks'],
#       dtype='object')

# %%
df.describe().T
# Out:
#            count       mean        std   min      25%   50%     75%    max
# wage      1260.0   6.306690   4.660639  1.02   3.7075   5.3   7.695  77.72
# exper     1260.0  18.206349  11.963485  0.00   8.0000  15.0  27.000  48.00
# union     1260.0   0.272222   0.445280  0.00   0.0000   0.0   1.000   1.00
# goodhlth  1260.0   0.933333   0.249543  0.00   1.0000   1.0   1.000   1.00
# black     1260.0   0.073810   0.261564  0.00   0.0000   0.0   0.000   1.00
# female    1260.0   0.346032   0.475892  0.00   0.0000   0.0   1.000   1.00
# married   1260.0   0.691270   0.462153  0.00   0.0000   1.0   1.000   1.00
# service   1260.0   0.273810   0.446089  0.00   0.0000   0.0   1.000   1.00
# educ      1260.0  12.563492   2.624489  5.00  12.0000  12.0  13.000  17.00
# looks     1260.0   3.185714   0.684877  1.00   3.0000   3.0   4.000   5.00

# %%
df["wage"].median(),
# Out:
# 5.3

# %%
df["wage"].mean()
# Out:
# 6.306690476190469

# %%
df["wage"].max()
# Out:
# 77.72

# %%
df["wage"].min()
# Out:
# 1.02

# %%
df["looks"].unique()
# Out:
# array([4, 3, 2, 5, 1], dtype=int64)

# %%
df["looks"].value_counts()
# Out:
# 3    722
# 4    364
# 2    142
# 5     19
# 1     13
# Name: looks, dtype: int64

# %%
df["female"].value_counts()
# Out:
# 0    824
# 1    436
# Name: female, dtype: int64

# %%
df[df["female"] == 1]
# Out:
#        wage  exper  union  goodhlth  black  female  married  service  educ  \
# 0      5.73     30      0         1      0       1        1        1    14
# 1      4.28     28      0         1      0       1        1        0    12
# 2      7.96     35      0         1      0       1        0        0    10
# 5      3.91     20      0         0      0       1        1        0    12
# 8      5.00      5      0         1      0       1        0        0    16
# 9      3.89     12      0         1      0       1        0        0    12
# 10     3.45      3      0         1      0       1        0        0    12
# 18    10.44     10      0         1      0       1        0        0    17
# 19     7.69      7      0         1      0       1        1        1    16
# 44     4.95     20      0         1      1       1        0        1    14
# 50     9.16     19      1         1      0       1        1        1    17
# ...

# %%
df[df["female"] == 0]
# Out:
#        wage  exper  union  goodhlth  black  female  married  service  educ  \
# 3     11.57     38      0         1      0       0        1        1    16
# 4     11.42     27      0         1      0       0        1        0    16
# 6      8.76     12      0         1      0       0        1        0    16
# 7      7.69      5      1         1      0       0        0        0    16
# 11     4.03      6      0         1      0       0        1        0    16
# 12     5.14     19      0         1      0       0        1        1    17
# 13     3.00      8      0         1      0       0        0        1    16
# 14     7.99     12      0         1      0       0        1        0    16
# 15     6.01     17      0         1      0       0        1        0    16
# 16     5.16      7      0         1      0       0        1        0    17
# 17    11.54     12      0         1      0       0        1        1    17
# ...

# %%
df[df["female"] == 1]["wage"].mean()
# Out:
# 4.299357798165136

# %%
df[df["female"] == 0]["wage"].mean()
# Out:
# 7.3688228155339734

# %%
df[df["female"] == 1]["wage"].max()
# Out:
# 77.72

# %%
df[df["female"] == 0]["wage"].max()
# Out:
# 41.67

# %%
df[(df["female"] == 1) & (df["goodhlth"] == 1)]
# Out:
#        wage  exper  union  goodhlth  black  female  married  service  educ  \
# 0      5.73     30      0         1      0       1        1        1    14
# 1      4.28     28      0         1      0       1        1        0    12
# 2      7.96     35      0         1      0       1        0        0    10
# 8      5.00      5      0         1      0       1        0        0    16
# 9      3.89     12      0         1      0       1        0        0    12
# 10     3.45      3      0         1      0       1        0        0    12
# 18    10.44     10      0         1      0       1        0        0    17
# 19     7.69      7      0         1      0       1        1        1    16
# 44     4.95     20      0         1      1       1        0        1    14
# 50     9.16     19      1         1      0       1        1        1    17
# 51     6.91     14      0         1      0       1        0        1    17
# ...

# %%
round(df[df["female"] == 1]["wage"].max(),0)
# Out:
# 78.0

# %% [markdown]
# # Задача к данным
#
# Какова максимальная зарплата среди мужчин, имеющих членство в профсоюзе и с опытом работа до 10 лет.

# %%
df[(df["female"] == 0) & (df["union"] == 1) & (df["exper"] < 10)]["wage"].max()
# Out:
# 12.82

# %%
df.sort_values(by = "wage")
# Out:
#        wage  exper  union  goodhlth  black  female  married  service  educ  \
# 1214   1.02     11      0         1      0       1        1        1    13
# 1009   1.05     29      0         1      1       0        1        0     5
# 1226   1.09      8      0         1      0       1        1        1    10
# 462    1.16      2      0         1      0       1        0        0    13
# 597    1.16      5      0         1      0       1        1        1    10
# 1138   1.17      1      0         1      1       0        0        0    12
# 874    1.20      4      0         1      0       1        1        0    12
# 845    1.20      5      0         1      0       1        1        0    12
# 1253   1.22     10      0         1      0       1        0        1     5
# 502    1.25      5      0         1      0       1        1        0    12
# 1149   1.26     32      0         1      1       1        0        0     5
# ...

# %%
df.sort_values(by = "wage", ascending=False)
# Out:
#        wage  exper  union  goodhlth  black  female  married  service  educ  \
# 602   77.72      9      1         1      1       1        1        1    13
# 269   41.67     16      0         0      0       0        1        0    13
# 415   38.86     29      0         1      0       0        1        0    13
# 69    32.79     33      0         1      0       0        1        1    16
# 290   31.09     32      0         0      0       0        1        0    13
# 68    29.98     12      0         1      0       0        1        1    17
# 1113  26.24     37      0         1      0       0        1        0    12
# 1108  26.24     37      0         1      0       0        1        0    12
# 299   26.24     24      0         1      0       0        1        0    12
# 396   26.22     17      0         1      0       0        1        1    17
# 1044  25.64     13      0         1      0       0        1        0    10
# ...

# %%
df[df["female"] == 0].sort_values(by = "wage", ascending=False)
# Out:
#        wage  exper  union  goodhlth  black  female  married  service  educ  \
# 269   41.67     16      0         0      0       0        1        0    13
# 415   38.86     29      0         1      0       0        1        0    13
# 69    32.79     33      0         1      0       0        1        1    16
# 290   31.09     32      0         0      0       0        1        0    13
# 68    29.98     12      0         1      0       0        1        1    17
# 299   26.24     24      0         1      0       0        1        0    12
# 1113  26.24     37      0         1      0       0        1        0    12
# 1108  26.24     37      0         1      0       0        1        0    12
# 396   26.22     17      0         1      0       0        1        1    17
# 338   25.64     28      0         1      0       0        1        0    16
# 1044  25.64     13      0         1      0       0        1        0    10
# ...

# %%
df.sort_values(by = ["female", "wage"])
# Out:
#        wage  exper  union  goodhlth  black  female  married  service  educ  \
# 1009   1.05     29      0         1      1       0        1        0     5
# 1138   1.17      1      0         1      1       0        0        0    12
# 993    1.27      4      0         1      0       0        0        0    12
# 271    1.32      2      1         1      0       0        1        0    10
# 1102   1.32     21      0         0      0       0        1        0    10
# 1145   1.46      2      0         1      1       0        1        0    10
# 777    1.48     13      0         1      0       0        0        1    12
# 1233   1.56      4      0         1      0       0        0        0    12
# 1210   1.58     27      0         1      0       0        1        1    12
# 330    1.63     16      0         1      0       0        1        1    10
# 800    1.65      7      0         1      0       0        0        0    10
# ...

# %%
df.sort_values(by = [ "wage", "female"])
# Out:
#        wage  exper  union  goodhlth  black  female  married  service  educ  \
# 1214   1.02     11      0         1      0       1        1        1    13
# 1009   1.05     29      0         1      1       0        1        0     5
# 1226   1.09      8      0         1      0       1        1        1    10
# 462    1.16      2      0         1      0       1        0        0    13
# 597    1.16      5      0         1      0       1        1        1    10
# 1138   1.17      1      0         1      1       0        0        0    12
# 845    1.20      5      0         1      0       1        1        0    12
# 874    1.20      4      0         1      0       1        1        0    12
# 1253   1.22     10      0         1      0       1        0        1     5
# 502    1.25      5      0         1      0       1        1        0    12
# 1149   1.26     32      0         1      1       1        0        0     5
# ...

# %% [markdown]
# # Визуализация

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/beauty.csv", sep = ";")

# %%
df.head()
# Out:
#     wage  exper  union  goodhlth  black  female  married  service  educ  looks
# 0   5.73     30      0         1      0       1        1        1    14      4
# 1   4.28     28      0         1      0       1        1        0    12      3
# 2   7.96     35      0         1      0       1        0        0    10      4
# 3  11.57     38      0         1      0       0        1        1    16      3
# 4  11.42     27      0         1      0       0        1        0    16      3

# %%
df.plot(subplots=True, figsize = (15,10));

# %%
df.hist(figsize=(10,10));

# %%
df["wage"].hist()

# %%
df.boxplot();

# %%
df.boxplot("wage")

# %%
plt.scatter(df["looks"], df["wage"])

# %%
plt.scatter(df["looks"], df["exper"])

# %%
plt.scatter(df["looks"], df["educ"])

# %%
pd.plotting.scatter_matrix(df[["wage", "educ", "exper", "female", "looks"]], figsize = (15,10));

# %%
import seaborn as sns

# %%
sns.pairplot(df[["wage", "educ", "exper", "female", "looks"]]);

# %%
sns.scatterplot(df["looks"], df["wage"])
plt.grid();

# %%
sns.boxplot(df["looks"], df["educ"])

# %%
df.boxplot(column="exper", by = "looks")

# %%
sns.countplot(df["female"])

# %%
df["female"].value_counts()
# Out:
# 0    824
# 1    436
# Name: female, dtype: int64

# %%
sns.violinplot(df["looks"], df["exper"])

# %%
sns.boxplot(df["looks"], df["exper"])

# %% [markdown]
# # Корреляции

# %%
df.corr()
# Out:
#               wage     exper     union  goodhlth     black    female  \
# wage      1.000000  0.234632  0.094529  0.006756 -0.059052 -0.313419
# exper     0.234632  1.000000  0.089792 -0.131609  0.007566 -0.247209
# union     0.094529  0.089792  1.000000 -0.022398  0.031939 -0.100037
# goodhlth  0.006756 -0.131609 -0.022398  1.000000 -0.034073 -0.039684
# black    -0.059052  0.007566  0.031939 -0.034073  1.000000  0.113703
# female   -0.313419 -0.247209 -0.100037 -0.039684  0.113703  1.000000
# married   0.184521  0.255607  0.053629 -0.013315 -0.133306 -0.319228
# service  -0.053653 -0.057328 -0.103633  0.049947  0.017261  0.267961
# educ      0.212333 -0.186200 -0.096022  0.107129 -0.138157  0.009105
# looks     0.055019 -0.155035 -0.043495  0.058558  0.012098  0.017129
#
#            married   service      educ     looks
# wage      0.184521 -0.053653  0.212333  0.055019
# exper     0.255607 -0.057328 -0.186200 -0.155035
# union     0.053629 -0.103633 -0.096022 -0.043495
# ...

# %%
sns.heatmap(df.corr(), annot = True, fmt = ".1f");
